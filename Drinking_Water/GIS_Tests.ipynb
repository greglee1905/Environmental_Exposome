# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
#Read in the Data
Counties = gpd.read_file('Counties')
Permitted_Uranium = gpd.read_file('C:\\Users\\u0890227\\Hanson_Lab\\\Radiation\\PermittedUraniumMines')
Uran_Area_Bounds = gpd.read_file('C:\\Users\\u0890227\\Hanson_Lab\\\Radiation\\UraniumAreaBoundaries')
Uran_Districts = gpd.read_file('C:\\Users\\u0890227\\Hanson_Lab\\\Radiation\\UraniumDistricts_UGS')
Uran_Past_Producers = gpd.read_file('C:\\Users\\u0890227\\Hanson_Lab\\\Radiation\\UraniumPastProducers')

#What are the datatypes
print(Permitted_Uranium.geom_type[2])
print(Uran_Districts.geom_type[2])
print(Uran_Past_Producers.geom_type[2])
# Out:
# Point
# Polygon
# Point

# %%
Uran_Past_Producers
# Out:
#         ZID   REC_NO REC_TYPE                       DEP_NUM REP_DATE INFO_SRC  \
# 0      1092  DC13173      X1B              23-GRANITE MTN-3    74 06        3
# 1      4645  DB01831      X1N  025-CLEAR CREEK MOUNTAIN-013    78 12       13
# 2     10182  W027044      X1N               37 - OLJETO - 3    77 06     None
# 3     10583  W028475      X1N               37 - OLJETO - 2    77 07     None
# 4     10183  W027045      X1N               37 - OLJETO - 5    77 06     None
# ...     ...      ...      ...                           ...      ...      ...
# 1211   None     None     None                          None     None     None
# 1212   None     None     None                          None     None     None
# 1213   None     None     None                          None     None     None
# 1214   None     None     None                          None     None     None
# 1215   None     None     None                          None     None     None
#
# ...

# %%
#Plotting
fig,(ax) = plt.subplots(ncols=1,nrows=1)
fig.set_size_inches(10,8)
ax2 = Counties.plot(ax =ax)
ax = Uran_Past_Producers.plot(ax =ax,cmap='OrRd')
ax.set_title("Permitted Uranium Area Boundaries");


plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Asbestos: Exploration
Asbestos = gpd.read_file('asbestos-fUS49')

#Information:
print("Type of Data: " + str(Asbestos.geom_type[1]))
print("EPSG: " + str(Asbestos.crs))
print("Shape of Data: " + str(Asbestos.shape))
# Out:
# Type of Data: Point
# EPSG: {'init': 'epsg:4267'}
# Shape of Data: (7, 12)

# %%
# Mineplants
Minplants = gpd.read_file('mineplant-fUS49')

#Information:
print("Type of Data: " + str(Minplants.geom_type[1]))
print("EPSG: " + str(Minplants.crs))
print("Shape of Data: " + str(Minplants.shape))
# Out:
# Type of Data: Point
# EPSG: {'init': 'epsg:4267'}
# Shape of Data: (132, 10)

# %%
#Utah Mining Districts
Utah_Mine_Distrits = gpd.read_file('UtahMiningDistrictsGIS')

#Information:
print("Type of Data: " + str(Utah_Mine_Distrits.geom_type[1]))
print("EPSG: " + str(Utah_Mine_Distrits.crs))
print("Shape of Data: " + str(Utah_Mine_Distrits.shape))
# Out:
# Type of Data: Polygon
# EPSG: {'init': 'epsg:26712'}
# Shape of Data: (188, 10)

# %%
#Plotting
fig,(ax) = plt.subplots(ncols=1,nrows=1)
fig.set_size_inches(10,8)
ax2 = Counties.plot(ax =ax)
ax = Utah_Mine_Distrits.plot(ax =ax,cmap='OrRd')
ax.set_title("Utah Mining Districts");
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Some sort of census data. Not fully sure
Census_Data = gpd.read_file('bg49_d90_shp')

#Information:
print("Type of Data: " + str(Census_Data.geom_type[1]))
print("EPSG: " + str(Census_Data.crs))
print("Shape of Data: " + str(Census_Data.shape))
# Out:
# Type of Data: Polygon
# EPSG: {}
# Shape of Data: (1343, 19)

# %%
#Plotting
fig,(ax) = plt.subplots(ncols=1,nrows=1)
fig.set_size_inches(10,8)

ax = Census_Data.plot(ax =ax,cmap='OrRd')
ax.set_title("Utah Mining Districts");
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Some sort of census data. Not fully sure
geo_chem = gpd.read_file('Geochem-fUS49')

#Information:
print("Type of Data: " + str(geo_chem.geom_type[1]))
print("EPSG: " + str(geo_chem.crs))
print("Shape of Data: " + str(geo_chem.shape))
# Out:
# Type of Data: Point
# EPSG: {'init': 'epsg:4267'}
# Shape of Data: (773, 288)

# %%
#Name:Geochemistry of stream sediments in the US from the NURE-HSSR database by common geographic areas (NURESED)
nuresed = gpd.read_file('nuresed-fUS49')

#Information:
print("Type of Data: " + str(nuresed.geom_type[1]))
print("EPSG: " + str(nuresed.crs))
print("Shape of Data: " + str(nuresed.shape))
# Out:
# Type of Data: Point
# EPSG: {'init': 'epsg:4267'}
# Shape of Data: (17488, 146)

# %%
#Plotting
fig,(ax) = plt.subplots(ncols=1,nrows=1)
fig.set_size_inches(10,8)

ax = nuresed.plot(ax =ax,cmap='OrRd')
ax.set_title("Geochemistry of stream sediments in the US from the NURE-HSSR database by common geographic areas");
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Name: 
nuresed = gpd.read_file('family_search_places')

#Information:
print("Type of Data: " + str(nuresed.geom_type[1]))
print("EPSG: " + str(nuresed.crs))
print("Shape of Data: " + str(nuresed.shape))
# Out:
# Type of Data: None
# EPSG: {}
# Shape of Data: (47937, 8)

# %%
#Name: 
nuresed = gpd.read_file('tl_2010_51_bg00')

#Information:
print("Type of Data: " + str(nuresed.geom_type[1]))
print("EPSG: " + str(nuresed.crs))
print("Shape of Data: " + str(nuresed.shape))
# Out:
# Type of Data: Polygon
# EPSG: {'init': 'epsg:4269'}
# Shape of Data: (4749, 13)

# %%
#Plotting
fig,(ax) = plt.subplots(ncols=1,nrows=1)
fig.set_size_inches(10,8)

ax = nuresed.plot(ax =ax,cmap='OrRd')
ax.set_title("(?)");
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Name: ussoils survey
nuresed = gpd.read_file('ussoils')

#Information:
print("Type of Data: " + str(nuresed.geom_type[1]))
print("EPSG: " + str(nuresed.crs))
print("Shape of Data: " + str(nuresed.shape))
# Out:
# Type of Data: Point
# EPSG: {}
# Shape of Data: (1323, 56)

# %%
#Plotting
fig,(ax) = plt.subplots(ncols=1,nrows=1)
fig.set_size_inches(10,8)

ax = nuresed.plot(ax =ax,cmap='OrRd')
ax.set_title("(?)");
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
ass_water = gpd.read_file('C:\\Users\\u0890227\\Hanson_Lab\\\DEQWaterMonitoring\\DEQWaterMonitoring_shp\\DWQGroundWaterPermits_shp\\DWQGroundWaterPermits\\')

#Information:
print("Type of Data: " + str(ass_water.geom_type[1]))
print("EPSG: " + str(ass_water.crs))
print("Shape of Data: " + str(ass_water.shape))
# Out:
# Type of Data: Point
# EPSG: {'init': 'epsg:26912'}
# Shape of Data: (53, 19)

# %%
#Plotting
fig,(ax) = plt.subplots(ncols=1,nrows=1)
fig.set_size_inches(10,8)
ax2 = Counties.plot(ax =ax)
ax = ass_water.plot(ax =ax,cmap='OrRd')
ax.set_title("Utah DEQ Water Monitoring");
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
Minerals = gpd.read_file('Minerals')

#Information:
print("Type of Data: " + str(ass_water.geom_type[1]))
print("EPSG: " + str(ass_water.crs))
print("Shape of Data: " + str(ass_water.shape))
# Out:
# Type of Data: Point
# EPSG: {'init': 'epsg:26912'}
# Shape of Data: (7986, 153)

# %%
Uranium.crs
# Out:
# {'init': 'epsg:26912'}

# %%
Counties.crs
# Out:
# {'init': 'epsg:26912'}

# %%
import numpy as np
a = np.array([5,6,7,8,9,10,11,12])
print(np.divide(368.25,a))
# Out:
# [73.65       61.375      52.60714286 46.03125    40.91666667 36.825
#  33.47727273 30.6875    ]
